# %% [markdown]
# # 03. Agregar o eliminar datos con Pandas
#
# - El método que nos permite eliminar datos de un dataframe es el método drop, su parámetro principal es la ubicaión de los datos a borrar, tambien podemos indicar el eje de borrado con el parámetro axis (0 para borrar una fila y 1 para borrar una columna)
#
# - También podemos usar método nativo de python del: del df[col]
#
# - En el caso querramos agregar una nueva columna lo hacemos declarando esta columna: df[col] = data
#
# - Para agregar una nueva fila usamos el método append: df.append(data)

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cargar DataFrame

# %%
df_books = pd.read_csv('./bd/bestsellers-with-categories.csv',sep=',',header=0)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ## Drop columns

# %%
df_books.drop('Genre', axis=1).head() #axis 1 = columnas. axis 2 = filas
# Elimina la columna Genre de la salida pero no del dataFrame

# %%
df_books.drop('Genre',axis=1,inplace=True) # Se borra directo del data frame

# %%
df_books = df_books.drop('Year',axis=1)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350
# 1              11/22/63: A Novel  Stephen King          4.6     2052

# %%
del df_books['Price'] # Elimina la columna Price del dataFrame, funcion propia de Python

# %% [markdown]
# ## Drop rows

# %%
df_books.head(2)
# Out:
#                             Name        Author  ...  Year        Genre
# 0  10-Day Green Smoothie Cleanse      JJ Smith  ...  2016  Non Fiction
# 1              11/22/63: A Novel  Stephen King  ...  2011      Fiction
#
# [2 rows x 7 columns]

# %%
df_books.drop(0, axis=0) # Elimina la fila 0 del dataFrame

# %%
df_books.drop([0,1,2], axis=0) # Elimina las filas 0, 1 y 2 del dataFrame

# %%
df_books.drop(range(0,10),axis=0).head(2) # Elimina las primeras 10 filas del dataFrame
# Out:
#                                                  Name  ...        Genre
# 10                          A Man Called Ove: A Novel  ...      Fiction
# 11  A Patriot's History of the United States: From...  ...  Non Fiction
#
# [2 rows x 7 columns]

# %% [markdown]
# ## Add columns

# %%
df_books.head(2)
# Out:
#                             Name        Author  ...  Year        Genre
# 0  10-Day Green Smoothie Cleanse      JJ Smith  ...  2016  Non Fiction
# 1              11/22/63: A Novel  Stephen King  ...  2011      Fiction
#
# [2 rows x 7 columns]

# %%
df_books['Nueva_Columna'] = np.nan 
df_books.head(2)
# Crea una nueva columna con el nombre de Nueva_columna de valores Nan
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nueva_Columna
# 0  2016  Non Fiction            NaN
# 1  2011      Fiction            NaN

# %%
data = np.arange(0,df_books.shape[0]) # Mostrar el numero de filas(0) o columnas(1) que tiene un dataFrame

# %%
df_books['Rango'] = data # Crea una nueva columna llamada Rango con los valores del array

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Add rows
# Para añadir filas se utiliza la funcion append de Python añadiendo como parámetro una lista, diccionario o añadiendo los valores manualmente.

# %%
df_books.append(df_books) # Duplica las filas del data Frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_42328/413862202.py in ?()
# ----> 1 df_books.append(df_books) # Duplica las filas del data Frame
#
# /mnt/d/Repository GitHub/Project-Pandas-Numpy/env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
